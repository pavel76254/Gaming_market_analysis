# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Привет еще раз. Спасибо, что доделал работу. Оформление комментариев по работе сохраняется. Только обозначим, что это вторая итерация.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Привет, Павел! Спасибо, что прислал задание:) Меня зовут Слепцов Артем и я буду проверять твой проект) Ты проделал большую работу над проектом, однако его еще можно улучшить. Будет здорово, если ты, надеюсь, не против, если я буду на ты, будешь отвечать на комментарии и участвовать в диалоге.
#
# Мои комментарии обозначены пометкой **Комментарий ревьюера**. Далее в файле ты сможешь найти их в похожих ячейках (если фон комментария <font color=green>зелёный</font> - всё сделано правильно. Рекомендации укажу таким же цветом; <font color=orange>оранжевый</font> - некритичные замечания. Если таких замечаний меньше трех - проект может быть принят без их отработки; <font color=red>красный</font> - нужно переделать). Не удаляй эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Артём, привет! Благодарю за отзыв. Да, обращение на ты мне гораздо удобнее. По максимому учёл все твои рекомендации и исправил. Артём, у меня не получилось нормально сделать гиперссылки, т.е. при нажатии на ссылку, не было попадания в точку назначения ноутбука. Поэтому решил пока оставить так. Свои исправления помечал оглавлением Ответ и Дополнено. Мне хотелось также выделять ячейки цветом, как и ты, но я пока не нашёл, как это граммотно сделать.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Можно вот так вот выделять.
#
# </div>

# %% [markdown]
# Описание проекта
# ===
#
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Не важно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
#
# Описание данных games.csv
#
# *	Name — название игры
# *	Platform — платформа
# *	Year_of_Release — год выпуска
# *	Genre — жанр игры
# *	NA_sales — продажи в Северной Америке (миллионы долларов)
# *	EU_sales — продажи в Европе (миллионы долларов)
# *	JP_sales — продажи в Японии (миллионы долларов)
# *	Other_sales — продажи в других странах (миллионы долларов)
# *	Critic_Score — оценка критиков (от 0 до 100)
# *	User_Score — оценка пользователей (от 0 до 10)
# *	Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
# Данные за 2016 год могут быть неполными.
# Инструкция по выполнению проекта
#
# Шаг 2. Откройте файл с данными и изучите общую информацию
#
# Путь к файлу: /datasets/games.csv Скачать датасет
#
# Шаг 3. Подготовьте данные
# *	Замените названия столбцов (приведите к нижнему регистру);
# *	Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
# *	Обработайте пропуски при необходимости:
# *	Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
# *	Опишите причины, которые могли привести к пропускам;
# *	Обратите внимание на аббревиатуру 'tbd' в столбцах с рейтингом. Поясните, как обработать это значение.
# *	Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.
#
# Шаг 4. Проведите исследовательский анализ данных
# *	Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# *	Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. Найдите популярные в прошлом платформы, у которых сейчас продажи на нуле. За какой характерный период появляются новые и исчезают старые платформы?
# *	Определите, данные за какой период нужно взять, чтобы исключить значимое искажение распределения по платформам в 2016 году.
# *	Далее работайте только с данными, которые вы определили. Не учитывайте данные за предыдущие годы.
# *	Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
# *	Постройте график «ящик с усами» по глобальным продажам каждой игры и разбивкой по платформам. Велика ли разница в продажах? А в средних продажах на разных платформах? Опишите результат.
# *	Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы и соотнесите их с продажами игр на других платформах.
# *	Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# Шаг 5. Составьте портрет пользователя каждого региона
# Определите для пользователя каждого региона (NA, EU, JP):
# *	Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# *	Самые популярные жанры (топ-5). Поясните разницу.
# *	Влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
# Шаг 6. Проведите исследование статистических показателей
# *	Как изменяется пользовательский рейтинг и рейтинг критиков в различных жанрах? Посчитайте среднее количество, дисперсию и стандартное отклонение. Постройте гистограммы. Опишите распределения
#
# Шаг 7. Проверьте гипотезы
# *	Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# *	Средние пользовательские рейтинги жанров Action (англ. «действие») и Sports (англ. «виды спорта») разные.
# Задайте самостоятельно пороговое значение alpha.
# Поясните:
# *	Как вы сформулировали нулевую и альтернативную гипотезы;
# *	Какой критерий применили для проверки гипотез и почему.
#
# Шаг 8. Напишите общий вывод
# Оформление: Выполните задание в Jupyter Notebook. Заполните программный код в ячейках типа code, текстовые пояснения — в ячейках типа markdown. Примените форматирование и заголовки.
#
# Как будут проверять мой проект?
# Мы подготовили критерии оценки проекта. Прежде чем решать кейс, внимательно изучите их.
# На что обращают внимание наставники, когда проверяют ваш проект:
# *	Как вы описываете выявленные в данных проблемы?
# *	Как готовите датасет к анализу?
# *	Какие строите графики для распределений и как их объясняете?
# *	Как рассчитываете стандартное отклонение и дисперсию?
# *	Формулируете ли альтернативную и нулевую гипотезы?
# *	Какие методы применяете, чтобы их проверить?
# *	Объясняете результат проверки гипотезы или нет?
# *	Соблюдаете ли структуру проекта и поддерживаете аккуратность кода?
# *	Какие выводы делаете?
# *	Оставляете ли комментарии к шагам?
#
# Всё необходимое, чтобы выполнить проект, есть в шпаргалках и конспектах прошлых тем.
# Успехов!

# %% [markdown]
# # Описание проекта
#
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Не важно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
#
# **Описание данных games.csv**
#
#     Name — название игры
#     Platform — платформа
#     Year_of_Release — год выпуска
#     Genre — жанр игры
#     NA_sales — продажи в Северной Америке (миллионы долларов)
#     EU_sales — продажи в Европе (миллионы долларов)
#     JP_sales — продажи в Японии (миллионы долларов)
#     Other_sales — продажи в других странах (миллионы долларов)
#     Critic_Score — оценка критиков (от 0 до 100)
#     User_Score — оценка пользователей (от 0 до 10)
#     Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board).
#     Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Данные за 2016 год могут быть неполными.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Вступление в работу очень важно. Так ты поясняешь то, чему она посвящена. Цель работы также хорошо бы вынести в отдельный блок вступления. Еще лучше будет, если ты сделаешь план работы с гиперссылками. Да, есть плагин ToC. Но хорошо бы уметь реализовывать интерактивный план проекта вручную. Как это реализовать - смотри по [ссылке](https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704).
#
# </div>

# %% [markdown]
# # Шаг 2. Откройте файл с данными и изучите общую информацию
# Путь к файлу: /datasets/games.csv Скачать датасет

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Я заметил, что ячейки в твоей тетрадке начинаются не с 1. Перед отправкой работы рекомендую перезапускать ноутбук, чтобы убедиться, что все ячейки выполняются корректно.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Перезапуск проекта позволяет обнаружить и исправить скрытые в коде ошибки.
#
# </div>

# %%
from scipy import stats as st
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Правильно, что весь импорт ты проводишь в первой ячейке работы. Так твой коллега, запускающий работу, будет в курсе используемых в ней библиотек и сможет при необходимости быстро настроить окружение.
#
# </div>

# %%
df=pd.read_csv('/datasets/games.csv')

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# Name               16713 non-null object
# Platform           16715 non-null object
# Year_of_Release    16446 non-null float64
# Genre              16713 non-null object
# NA_sales           16715 non-null float64
# EU_sales           16715 non-null float64
# JP_sales           16715 non-null float64
# Other_sales        16715 non-null float64
# Critic_Score       8137 non-null float64
# User_Score         10014 non-null object
# Rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# В столбцах Name, Year_of_Release, Genre, Critic_Score, User_Score, Rating есть отсутствующие значения

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Подумай также о возможных причинах появления пропусков, а также о том, являются ли они случайными или нет. Можно высказать предварительные варианты их обработки.
#
# Первый взгляд на таблицу выполнен.
#
# </div>

# %% [markdown]
# # Шаг 3. Подготовьте данные
#
# * Замените названия столбцов (приведите к нижнему регистру);
# * Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
# * Обработайте пропуски при необходимости:
#         Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
#         Опишите причины, которые могли привести к пропускам;
#         Обратите внимание на аббревиатуру 'tbd' в столбцах с рейтингом. Поясните, как обработать это значение.
# * Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.

# %% [markdown]
# Приведём столбцы к нижнему регистру.

# %%
df.columns = df.columns.str.lower()

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Данный метод позволяет нам автоматизировать процесс приведения названий столбцов к нижнему регистру. Так исключается вероятность опечаток.
#
# </div>

# %%
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# name               16713 non-null object
# platform           16715 non-null object
# year_of_release    16446 non-null float64
# genre              16713 non-null object
# na_sales           16715 non-null float64
# eu_sales           16715 non-null float64
# jp_sales           16715 non-null float64
# other_sales        16715 non-null float64
# critic_score       8137 non-null float64
# user_score         10014 non-null object
# rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Преобразование данных в необходимые типы:
# * Поле 'year_of_release' тип данных float64, преобразуем в значение в тип int, т.к. в данном анализе данных нет необходимости использовать тип дата;
# * Поле 'critic_score' преобразуем в тип int, т.к. значения этого поля представляет собой целочисленный тип;
# * Поле 'rating' преобразуем во float64, т.к. это поле использует дробные значения.
#
# Т.к. указанные поля содержат пустые значения, а поле 'rating' содержит ещё и текстовое значение 'tbd', то преобразование типов произведём после обработки пустых значений.

# %% [markdown]
# Количество всех пустых значений в данных:

# %%
df.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %% [markdown]
# ### Обработка отсутствующих значений в поле 'year_of_release'

# %%
df[df['year_of_release'].isna()].head()
# Out:
#                            name platform  year_of_release     genre  na_sales  \
# 183             Madden NFL 2004      PS2              NaN    Sports      4.26
# 377            FIFA Soccer 2004      PS2              NaN    Sports      0.59
# 456  LEGO Batman: The Videogame      Wii              NaN    Action      1.80
# 475  wwe Smackdown vs. Raw 2006      PS2              NaN  Fighting      1.57
# 609              Space Invaders     2600              NaN   Shooter      2.36
#
#      eu_sales  jp_sales  other_sales  critic_score user_score rating
# 183      0.26      0.01         0.71          94.0        8.5      E
# 377      2.36      0.04         0.51          84.0        6.4      E
# 456      0.97      0.00         0.29          74.0        7.9   E10+
# 475      1.02      0.00         0.41           NaN        NaN    NaN
# 609      0.14      0.00         0.03           NaN        NaN    NaN

# %% [markdown]
# Заполним отсутствующие значения даты 0.

# %%
df['year_of_release']=df['year_of_release'].fillna(0)
df['year_of_release'].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2016., 2003., 1986., 2000.,    0., 1995., 1991., 1981., 1987.,
#        1980., 1983.])

# %% [markdown]
# Преобразуем тип поля 'year_of_release' в int.

# %%
df['year_of_release']=df['year_of_release'].astype('int')
df[df['year_of_release']==0].head()
# Out:
#                            name platform  year_of_release     genre  na_sales  \
# 183             Madden NFL 2004      PS2                0    Sports      4.26
# 377            FIFA Soccer 2004      PS2                0    Sports      0.59
# 456  LEGO Batman: The Videogame      Wii                0    Action      1.80
# 475  wwe Smackdown vs. Raw 2006      PS2                0  Fighting      1.57
# 609              Space Invaders     2600                0   Shooter      2.36
#
#      eu_sales  jp_sales  other_sales  critic_score user_score rating
# 183      0.26      0.01         0.71          94.0        8.5      E
# 377      2.36      0.04         0.51          84.0        6.4      E
# 456      0.97      0.00         0.29          74.0        7.9   E10+
# 475      1.02      0.00         0.41           NaN        NaN    NaN
# 609      0.14      0.00         0.03           NaN        NaN    NaN

# %%
df[df['name']=='Madden NFL 2004']
# Out:
#                  name platform  year_of_release   genre  na_sales  eu_sales  \
# 183   Madden NFL 2004      PS2                0  Sports      4.26      0.26
# 1881  Madden NFL 2004       XB             2003  Sports      1.02      0.02
# 3889  Madden NFL 2004       GC             2003  Sports      0.40      0.10
# 5708  Madden NFL 2004      GBA             2003  Sports      0.22      0.08
#
#       jp_sales  other_sales  critic_score user_score rating
# 183       0.01         0.71          94.0        8.5      E
# 1881      0.00         0.05          92.0        8.3      E
# 3889      0.00         0.01          94.0        7.7      E
# 5708      0.00         0.01          70.0        6.6      E

# %%
df[df['name']=='FIFA Soccer 2004']
# Out:
#                    name platform  year_of_release   genre  na_sales  eu_sales  \
# 377    FIFA Soccer 2004      PS2                0  Sports      0.59      2.36
# 2606   FIFA Soccer 2004       XB             2003  Sports      0.24      0.49
# 12029  FIFA Soccer 2004       GC             2003  Sports      0.05      0.01
# 13086  FIFA Soccer 2004      GBA             2003  Sports      0.04      0.01
#
#        jp_sales  other_sales  critic_score user_score rating
# 377        0.04         0.51          84.0        6.4      E
# 2606       0.00         0.05          82.0        8.2      E
# 12029      0.00         0.00          83.0        6.2      E
# 13086      0.00         0.00          82.0        7.9      E

# %%
df[df['name']=='LEGO Batman: The Videogame']
# Out:
#                              name platform  year_of_release   genre  na_sales  \
# 397    LEGO Batman: The Videogame     X360             2008  Action      2.04
# 456    LEGO Batman: The Videogame      Wii                0  Action      1.80
# 460    LEGO Batman: The Videogame       DS             2008  Action      1.75
# 1519   LEGO Batman: The Videogame      PS3             2008  Action      0.72
# 1538   LEGO Batman: The Videogame      PSP                0  Action      0.57
# 1553   LEGO Batman: The Videogame      PS2             2008  Action      0.72
# 12465  LEGO Batman: The Videogame       PC             2008  Action      0.02
#
#        eu_sales  jp_sales  other_sales  critic_score user_score rating
# 397        1.02       0.0         0.32          76.0        7.9   E10+
# 456        0.97       0.0         0.29          74.0        7.9   E10+
# 460        1.01       0.0         0.29          72.0          8   E10+
# ...

# %% [markdown]
# Некоторые игры выпускались одновременно на нескольких платформах, поэтому для этих данных, значение даты можно взять с других платформ.

# %%
not_null_year = df[df['year_of_release']!=0]
def fill_year_of_release(row):
    col = 'year_of_release'
    rows = not_null_year[not_null_year['name'] == row['name']]
   
    if len(rows) > 0:
        return rows.iloc[0][col]
    else: return row[col]

# %% [markdown]
# Заполнение работает поля 'year_of_release' работает довольно долго.

# %%
# %time df['year_of_release'] = df.apply(fill_year_of_release, axis=1).astype('int')
# Out:
# CPU times: user 38.6 s, sys: 59.3 ms, total: 38.6 s
# Wall time: 38.8 s

# %% [markdown]
# Проверим, заполнились ли значения.

# %%
df[df['name']=='Madden NFL 2004']
# Out:
#                  name platform  year_of_release   genre  na_sales  eu_sales  \
# 183   Madden NFL 2004      PS2             2003  Sports      4.26      0.26
# 1881  Madden NFL 2004       XB             2003  Sports      1.02      0.02
# 3889  Madden NFL 2004       GC             2003  Sports      0.40      0.10
# 5708  Madden NFL 2004      GBA             2003  Sports      0.22      0.08
#
#       jp_sales  other_sales  critic_score user_score rating
# 183       0.01         0.71          94.0        8.5      E
# 1881      0.00         0.05          92.0        8.3      E
# 3889      0.00         0.01          94.0        7.7      E
# 5708      0.00         0.01          70.0        6.6      E

# %% [markdown]
# Ещё остались значения с пустым полем 'year_of_release'.

# %%
df[df['year_of_release']==0]

# %% [markdown]
# Можно ещё взять год издания игры из названия самой игры. Например, wwe Smackdown vs. Raw 2006, год издания 2006, но тогда возможно получить курьёзы вида: Метро 2033, год издания 2033, Cyberpunk 2077 - 2077. Хотя они отсеиваются фильтром, 1980 <= год <= 2016.

# %% [markdown]
# Данных с нулевым значением поля year_of_release не так много, по сравнению с общим кол-вом записей, поэтому сохраним эти записи в отдельную таблицу и удалим их из основной таблицы данных.

# %%
df_year_zero=df[df['year_of_release']==0]
df.drop(index=df[df['year_of_release']==0].index, inplace=True)
df_year_zero.head()

# %%
df[df['year_of_release']==0]
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating]
# Index: []

# %% [markdown]
# Возможно, что причина появления отсутствующих значений в поле year_of_release связана с техническими проблемами. Вполне возможно, что для некоторых игр действительно неизвестен год релиза.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Часть пропусков мы, действительно, можем восстановить выбранным тобой способом. Оставшиеся пропуски лучше оставить, а не удалять из данных. Однако их не так много. Их удаление не изменит результаты нашего анализа.
#
# </div>

# %% [markdown]
# ### Проверим записи с пустым значением поля 'name'.

# %%
df[df['name'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN             1993   NaN      1.78      0.53      0.00
# 14244  NaN      GEN             1993   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %% [markdown]
# Эти записи несущественны, т.к. в них ещё отсутствует данные о жанре и рейтингах. Удалим их. Возможно, что эти данные не загрузились из-за каких-либо технических ошибок, вроде ошибки ввода-вывода.

# %%
df.drop(df[df['name'].isna()].index , inplace=True)
df[df['name'].isna()]
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating]
# Index: []

# %%
df[df['genre'].isna()]
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating]
# Index: []

# %% [markdown]
# ### Обработаем пустые значения есть в полях rating, user_score, critic_score.

# %% [markdown]
# #### Поле rating

# %%
df['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %%
def count_na(df, pole):
    df_count=len(df)
    count_na=len(df[df[pole].isna()])
    print('Поле {}, не заполненных значений - {}, {:.2%} от всего набора данных.'.format(pole, count_na, count_na/df_count))

# %%
count_na(df, 'rating')
# Out:
# Поле rating, не заполненных значений - 6699, 40.44% от всего набора данных.

# %% [markdown]
# #### Поле user_score

# %%
df['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
count_na(df, 'user_score')
# Out:
# Поле user_score, не заполненных значений - 6633, 40.04% от всего набора данных.

# %% [markdown]
# #### Поле critic_score

# %%
df['critic_score'].unique()
# Out:
# array([76., nan, 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
#        65., 54., 20., 53., 37., 38., 33., 52., 30., 32., 43., 45., 51.,
#        40., 46., 39., 34., 35., 41., 36., 28., 31., 27., 26., 19., 23.,
#        24., 21., 17., 13.])

# %%
count_na(df, 'critic_score')
# Out:
# Поле critic_score, не заполненных значений - 8492, 51.26% от всего набора данных.

# %% [markdown]
# Рассмотрим значение tbd

# %%
len(df[df['user_score']=='tbd'])
# Out:
# 2394

# %% [markdown]
# To Be Determined, то есть "Будет определено". Т.е. пользователи ещё не определили рейтинг игры и рейтинг определиться в ближайшем будущем. Заменим tbd значением np.NaN

# %%
df['user_score'] = df['user_score'].replace('tbd', np.NaN)

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Верно, по своей сути tbd и является Nan. Отлично, что определяешь неявные пропущенные значения.
#
# </div>

# %% [markdown]
# Снова посмотрим на кол-во пустых значений поля 'user_score'.

# %%
count_na(df, 'user_score')
# Out:
# Поле user_score, не заполненных значений - 9027, 54.49% от всего набора данных.

# %% [markdown]
# * Поле rating, не заполненных значений - 6699, 40.44% от всего набора данных.
# * Поле user_score, не заполненных значений - 9027, 54.49% от всего набора данных.
# * Поле critic_score, не заполненных значений - 8492, 51.26% от всего набора данных.
#
# В этих полях слишком много пропусков, если их отбросить, то также отбросится существенная информация, что повлечёт за собой не правильные выводы по данным.

# %% [markdown]
# Пропуски в столбцах critic_score, user_score, rating - это индивидуальные характеристики каждой игры, поэтому, если заполнять их средним, медианым или модой, то это исказит данные и приведёт к неправильным выводам. Неизвестно по каким причинам произошла столь существенная потеря информации в данных, возможно стандартные технические ошибки ввода-вывода. В данной ситуации требуется обратиться к Data-инженерам, к специалистам, которые предоставили данные. Или произвести повторную загрузку данных с источника.

# %% [markdown]
# Преобразуем типы user_score, rating во float.

# %%
df['critic_score'] = df['critic_score'].astype('Int64')
df['user_score'] = df['user_score'].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16567 entries, 0 to 16714
# Data columns (total 11 columns):
# name               16567 non-null object
# platform           16567 non-null object
# year_of_release    16567 non-null int64
# genre              16567 non-null object
# na_sales           16567 non-null float64
# eu_sales           16567 non-null float64
# jp_sales           16567 non-null float64
# other_sales        16567 non-null float64
# critic_score       8075 non-null Int64
# user_score         7540 non-null float64
# rating             9868 non-null object
# dtypes: Int64(1), float64(5), int64(1), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# Посчитаем суммарные продажи.

# %%
df['total_sales'] = df['na_sales'] + df['eu_sales'] + df['jp_sales'] + df['other_sales']

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Да, восстановить пропущенные значения мы не можем. Данных для этого недостаточно. Лучше работать с меньшим количеством данных хорошего качества.
#
# Ошибки в данных устранены. Данные подготовлены к дальнейшему анализу.
#
# </div>

# %% [markdown]
# ### Поиск дубликатов в данных

# %% [markdown]
# Посмотрим, есть ли полные дубликаты строк.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Посмотрим, есть ли дублирующие записи с одной и той же игрой, на одной и той же платформе.

# %%
df_dup=df.groupby(by=['name', 'platform']).count()

# %%
df_dup[df_dup['year_of_release']>1]
# Out:
#                                       year_of_release  genre  na_sales  \
# name                        platform
# Madden NFL 13               PS3                     2      2         2
# Need for Speed: Most Wanted PC                      2      2         2
#                             X360                    2      2         2
# Sonic the Hedgehog          PS3                     2      2         2
#
#                                       eu_sales  jp_sales  other_sales  \
# name                        platform
# Madden NFL 13               PS3              2         2            2
# Need for Speed: Most Wanted PC               2         2            2
#                             X360             2         2            2
# Sonic the Hedgehog          PS3              2         2            2
#
#                                       critic_score  user_score  rating  \
# name                        platform
# ...

# %% [markdown]
# Обнаружены четыре записи с одинаковыми платформами и играми.

# %%
df.query('name=="Madden NFL 13" and platform=="PS3"')
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 604    Madden NFL 13      PS3             2012  Sports      2.11      0.22
# 16230  Madden NFL 13      PS3             2012  Sports      0.00      0.01
#
#        jp_sales  other_sales  critic_score  user_score rating  total_sales
# 604         0.0         0.23            83         5.5      E         2.56
# 16230       0.0         0.00            83         5.5      E         0.01

# %%
df.query('name=="Madden NFL 13"')['platform'].value_counts()
# Out:
# PS3     2
# PSV     1
# X360    1
# WiiU    1
# Wii     1
# Name: platform, dtype: int64

# %%
df.query('name=="Need for Speed: Most Wanted"')['platform'].value_counts()
# Out:
# X360    2
# PC      2
# PS2     1
# PSV     1
# XB      1
# DS      1
# WiiU    1
# PS3     1
# GC      1
# GBA     1
# Name: platform, dtype: int64

# %%
df.query('name=="Need for Speed: Most Wanted" and (platform=="X360" or platform=="PC")')
# Out:
#                               name platform  year_of_release   genre  \
# 1190   Need for Speed: Most Wanted     X360             2005  Racing
# 1591   Need for Speed: Most Wanted     X360             2005  Racing
# 5972   Need for Speed: Most Wanted       PC             2005  Racing
# 11715  Need for Speed: Most Wanted       PC             2005  Racing
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 1190       0.62      0.78      0.01         0.15            83         8.5
# 1591       1.00      0.13      0.02         0.10            83         8.5
# 5972       0.02      0.23      0.00         0.04            82         8.5
# 11715      0.00      0.06      0.00         0.02            82         8.5
#
#       rating  total_sales
# 1190       T         1.56
# 1591       T         1.25
# 5972       T         0.29
# 11715      T         0.08

# %%
df.query('name=="Sonic the Hedgehog"')['platform'].value_counts()
# Out:
# PS3     2
# GEN     1
# X360    1
# Name: platform, dtype: int64

# %%
df.query('name=="Sonic the Hedgehog" and platform=="PS3"')
# Out:
#                     name platform  year_of_release     genre  na_sales  \
# 1745  Sonic the Hedgehog      PS3             1991  Platform      0.41
# 4127  Sonic the Hedgehog      PS3             1991  Platform      0.00
#
#       eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 1745      0.06      0.04         0.66            43         4.1   E10+
# 4127      0.48      0.00         0.00            43         4.1   E10+
#
#       total_sales
# 1745         1.17
# 4127         0.48

# %% [markdown]
# Похоже, что эти дупликаты появились из-за того, что информация об играх появилась из разных источников о продажах. На это намекают одинаковые значения critic_score и user_score. Можно было бы сложить эти записи о продажах, но т.к. таких записей мало, то оставим их без изменений.

# %% [markdown]
# # Шаг 4. Проведите исследовательский анализ данных
# * Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# * Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. Найдите популярные в прошлом платформы, у которых сейчас продажи на нуле. За какой характерный период появляются новые и исчезают старые платформы?
# * Определите, данные за какой период нужно взять, чтобы исключить значимое искажение распределения по платформам в 2016 году.
# * Далее работайте только с данными, которые вы определили. Не учитывайте данные за предыдущие годы.
# * Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
# * Постройте график «ящик с усами» по глобальным продажам каждой игры и разбивкой по платформам. Велика ли разница в продажах? А в средних продажах на разных платформах? Опишите результат.
# * Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы и соотнесите их с продажами игр на других платформах.
# * Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами

# %% [markdown]
# • Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
ax = df['year_of_release'].plot(kind='hist', figsize=(10, 5), bins=37).set(ylabel='Частота')
plt.title('Распределение по годам релиза')
# Out:
# Text(0.5, 1.0, 'Распределение по годам релиза')

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Данный график отличается от того, что ниже. Мы это видим по данным за 2016 год. Подумай, почему мы получаем такой результат.
#
# </div>

# %% [markdown]
# ### Ответ
# Я добавил дополнительный bin в график гистограммы 36+1 за 2016 год, т.к. последние bin-ы учитывают информацию с 2015 по 2016 годы включительно.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Да, помарка была в этом. Теперь все верно.
#
# </div>

# %% [markdown]
# Кол-во выпущенных в зависимости от года.

# %%
games_per_year = (
    df[['name', 'year_of_release']]
        .pivot_table(index='year_of_release', values='name', aggfunc='count')
        .sort_values('year_of_release', ascending=False)
)

# %%
games_per_year
# Out:
#                  name
# year_of_release
# 2016              475
# 2015              581
# 2014              551
# 2013              535
# 2012              672
# 2011             1167
# 2010             1264
# 2009             1426
# 2008             1433
# 2007             1208
# 2006             1016
# 2005              933
# 2004              783
# 2003              747
# 2002              828
# 2001              526
# 2000              353
# 1999              331
# 1998              401
# 1997              301
# 1996              275
# 1995              212
# 1994              149
# 1993               61
# 1992               52
# 1991               50
# 1990               15
# 1989               21
# 1988               14
# 1987               16
# 1986               24
# 1985               17
# 1984               16
# 1983               19
# 1982               37
# 1981               44
# 1980               14

# %%
(games_per_year
        .plot(figsize=(12, 6), colormap='jet', legend=False, title='Количество игр по годам')
        .set(xlabel='Год релиза', ylabel='Кол-во')
)

plt.show()

# %% [markdown]
# Резкий рост выпуска игр наблюдается с 1990 года. Поэтому данные до 1990 года можно не принимать во внимание. Заметно, возрастающий тренд выпуска новых игр идёт до примерно 2007-2008 годов, затем наблюдается резкое снижение количества выпускаемых игр. На текущий момент кол-во выпускаемых игр снижается.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Как думаешь, почему мы наблюдаем спад в индустрии послених лет?
#
# </div>

# %% [markdown]
# ### Ответ
# Для более подробной информации пришлось спросить у yandex.
# * Выпускаемые игры шаблоны. Нет новизны, у большинства игр сюжет шаблонен и развивается по одному и тому же сценарию. Шаблоны и сами персонажи;
# * Замена интересного дизайна игрывых карт красивой картинкой и эффектами. Игровые карты слишком просты, примитивны, и неинтересны. А весь упор делается на красивые картинку и эффекты;
# * Упрощение игрового процесса, за счёт снижения вариативности развития;
# * Популярность игр для мобильных телефонов и планшетов;
#
# Вообщем, игры стали шаблоными, не проработанными и не интересными. Хотя, возможно добавление технологий виртуальной реальности может вернуть им популярность.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Отличный анализ 👍
#
# </div>

# %% [markdown]
# • Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. Найдите популярные в прошлом платформы, у которых сейчас продажи на нуле. За какой характерный период появляются новые и исчезают старые платформы?

# %%
total_sales_per_platform=(df
                          .pivot_table(index='platform', values='total_sales', aggfunc='sum')
                          .sort_values('total_sales', ascending=False)
                         )

# %%
total_sales_per_platform
# Out:
#           total_sales
# platform
# PS2           1247.16
# X360           966.61
# PS3            935.19
# Wii            903.31
# DS             804.28
# PS             727.58
# PS4            314.14
# GBA            313.73
# PSP            293.57
# PC             258.86
# 3DS            258.53
# XB             256.69
# GB             254.43
# NES            251.05
# N64            218.48
# SNES           200.04
# GC             198.66
# XOne           159.32
# 2600            89.01
# WiiU            82.19
# PSV             53.81
# SAT             33.59
# GEN             28.35
# DC              15.95
# SCD              1.86
# NG               1.44
# WS               1.42
# TG16             0.16
# 3DO              0.10
# GG               0.04
# PCFX             0.03

# %%
(total_sales_per_platform
                        .plot(kind='bar', y='total_sales', figsize=(10, 5), legend=False)
                        .set(xlabel='Платформа', ylabel='Глобальные продажи')
)
plt.show()

# %% [markdown]
# Больше всего продаж у платформ PS2, X360, PS3, Wii, DS, PS.

# %% [markdown]
# Посмотрим, как менялись продажи по платформам из топ 10 продаж.

# %%
total_10=total_sales_per_platform.head(10)

# %%
def platform_total_sales(df, name):
    return df.query("platform==@name").groupby('year_of_release')['total_sales'].sum()

# %%
def plot_platform_total_sales(df,platform):
     (platform_total_sales(df, platform)    
                    .plot(title=platform)
                    .set(xlabel='Год релиза', ylabel='Глобальные продажи')
     )

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999

# %%
import warnings
warnings.filterwarnings('ignore')

platforms = list(total_10.index)

# график из 5 строк
rows = 5
cols = (len(platforms) // rows)
fig, ax = plt.subplots(rows, cols)

# построение графиков продаж по каждой платформе
num = 0
for row in range(rows):
    for col in range(cols):
        platform = platforms[num]
        (
         platform_total_sales(df,platform)    
                .plot(ax=ax[row, col], figsize=(20, 20), title=platform)
                .set(xlabel='Год релиза', ylabel='Глобальные продажи')
        )
        num += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# * У платформ PS2, Wii, DS, PS, на текущий момент, продажи почти на нуле.
# * У платформ X360, PS3 наблюдается понижающий тренд продаж, приближающийся к нулю.
# * У платформ PS4 и PC наблюдается понижающийся тренд продаж.
# * Исходя из значений продаж срок жизни данных платформ от 7 до 12 лет.

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Значение средней продолжительности существования платформы приведено. Однако выводы ты делаешь по графикам. Стоит также привести расчет данного значения. Подумай, стоит ли включать в расчет все платформы. Будут ли выбросы по продолжительности существования платформ?
#
# </div>

# %% [markdown]
# ### Ответ
# Попробуем посчитать время жизни каждой игровой платформы.

# %%
df['platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
# Попробуем посчитать срок жизни игровых платформ по следующему критерию:
# Делаем выборку из данных по платформе,
# Далее считаем кол-во лет, когда на платформе было выпущено более 3-х игр
def platform_lives(df, name, games_count=3):
    platform_games_count=df.query("platform==@name").groupby('year_of_release')['total_sales'].count()
    years_lives=platform_games_count[platform_games_count>games_count].count()
    return years_lives

# %%
# Заполняем таблицу life_years_platform время жизни каждой игровой платформы
life_years_platform = pd.DataFrame(columns = ['name_platform', 'years'])
platforms=list(df['platform'].unique())
for i in range(len(platforms)):
    life_years_platform.loc[i]={'name_platform':platforms[i], 'years':platform_lives(df, platforms[i])}
life_years_platform['years']=life_years_platform['years'].astype('int')

# %%
life_years_platform
# Out:
#    name_platform  years
# 0            Wii     11
# 1            NES     10
# 2             GB     11
# 3             DS     12
# 4           X360     12
# 5            PS3     12
# 6            PS2     12
# 7           SNES      8
# 8            GBA      9
# 9            PS4      6
# 10           3DS      7
# 11           N64      6
# 12            PS     10
# 13            XB      7
# 14            PC     22
# 15          2600      5
# 16           PSP     12
# 17          XOne      5
# 18          WiiU      6
# 19            GC      7
# 20           GEN      3
# 21            DC      5
# 22           PSV      8
# 23           SAT      5
# 24           SCD      1
# 25            WS      0
# 26            NG      2
# 27          TG16      0
# 28           3DO      0
# 29            GG      0
# 30          PCFX      0

# %% [markdown]
# Построим график "ящик с усами", для параметра - years, время жизни игровой платформы.

# %%
life_years_platform.boxplot(column='years')

# %%
life_years_platform.describe()
# Out:
#            years
# count  31.000000
# mean    6.903226
# std     4.989020
# min     0.000000
# 25%     4.000000
# 50%     7.000000
# 75%    10.500000
# max    22.000000

# %% [markdown]
# Исходя из приведённых расчётов и диаграммы срок жизни платформ составляет от 7 до 12 лет. Среднее время и медианное время жизни игровых платформ приблизительно равны друг другу и составляет 7 лет. Т.е. поэтому критерию, данные можно взять с 2010 по 2016 годы включительно. Также можно не брать в расчёт платформы старше 7 лет. Один выброс по жизни PC, ну это не удивительно, для PC всегда будут выходить игры, в независимости от времени.

# %%
life_years_platform.query('years<=7 and years>0')
# Out:
#    name_platform  years
# 9            PS4      6
# 10           3DS      7
# 11           N64      6
# 13            XB      7
# 15          2600      5
# 17          XOne      5
# 18          WiiU      6
# 19            GC      7
# 20           GEN      3
# 21            DC      5
# 23           SAT      5
# 24           SCD      1
# 26            NG      2

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Отлично, расчет приведен. Только не стоило в него включать актуальные на настоящий момент платформы. Период их жизни еще продолжается.
#
# </div>

# %% [markdown]
# Построим график продаж по каждой игровой платформе.

# %%
platforms=list(df['platform'].unique())

rows = len(platforms)
fig, ax = plt.subplots(rows, figsize=(10, 120))

# построение графиков продаж по каждой платформе
num = 0
for row in range(rows):
    
    platform = platforms[num]
    (
      platform_total_sales(df,platform)    
             .plot(ax=ax[row], title=platform)
             .set(xlabel='Год релиза', ylabel='Глобальные продажи')
    )
    num += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# По платформам GG и PCFX нет данных. По части игровых платформ почти нулевые продажи, по другой части наблюдается снижающийся тренд продаж. Некоторые платформы уже морально устарели и для них уже не выпускаются игры. Срок жизни игровых платформ составляет от 7 до 12 лет, поэтому актуальный срок рассмотрения данных последние - 10 лет, с 2006 по 2016 годы. В целом, в игрофой индустрии наблюдается понижающийся тренд продаж игр. Возможно это связано, с тем, что большую полярность приобрели игры на мобильных устройствах. И также с тем, что идёт активное развитие технологии виртуальной реальности в играх, поэтому обычные приставочные игры уже не так интересны пользователям. Возможно, что ещё одна возможная причина снижения, это игры как GTA, когда человек как бы живёт виртуальной жизнью персонажа игры, т.е. для исследования и прохождения такой игры требуется очень много времени, даже годы, поэтому пользователи увлекаясь такой игрой, не тратят своё время и внимание на остальные игры.

# %% [markdown]
# Исходя из графиков стоит обратить внимание на платформы X360, PS3, PS4, 3DS, PC, XOne, WiiU, PSV.

# %% [markdown]
# * Определите, данные за какой период нужно взять, чтобы исключить значимое искажение распределения по платформам в 2016 году.
# * Далее работайте только с данными, которые вы определили. Не учитывайте данные за предыдущие годы.
# * Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
# * Постройте график «ящик с усами» по глобальным продажам каждой игры и разбивкой по платформам. Велика ли разница в продажах? А в средних продажах на разных платформах? Опишите результат.

# %% [markdown]
# Возьмём данные за последний 10 лет, с 2006 по 2016 годы.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Актуальный период назван. Лучше его уменьшить. Сейчас у тебя в периоде содержится 3 этапа развития индустрии: рост до 2008 года, пик 2008 и 2009 годов, а также сокращение рынка последних годов. Также большей части платформ уже нет в 2016 году, в построении прогноза на 2017 год они нам не помогут. При уменьшении периода в рассмотрение попадут только последние поколения платформ, а также будем рассматривать только конечный на данный момент интервал развития игровой индустрии.
#
# </div>

# %% [markdown]
# ### Ответ
# Предлагаю рассматривать данные с 2010 года, т.к. с 2010 начинается сокращение продаж игр и среднее время жизни платформы составляет 7 лет.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Да, анализ такого периода позволит нам увеличить точность и качество прогноза на 2017 год.
#
# </div>

# %%
games_per_year.loc[:2010]
# Out:
#                  name
# year_of_release
# 2016              475
# 2015              581
# 2014              551
# 2013              535
# 2012              672
# 2011             1167
# 2010             1264

# %%
#actual_period = df.query('year_of_release > 2006')
actual_period = df.query('year_of_release >= 2010')
actual_period.head()
# Out:
#                               name platform  year_of_release         genre  \
# 14              Kinect Adventures!     X360             2010          Misc
# 16              Grand Theft Auto V      PS3             2013        Action
# 23              Grand Theft Auto V     X360             2013        Action
# 27     Pokemon Black/Pokemon White       DS             2010  Role-Playing
# 29  Call of Duty: Modern Warfare 3     X360             2011       Shooter
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 14     15.00      4.89      0.24         1.69            61         6.3
# 16      7.02      9.09      0.98         3.96            97         8.2
# 23      9.66      5.14      0.06         1.41            97         8.1
# 27      5.51      3.17      5.65         0.80           NaN         NaN
# 29      9.04      4.24      0.13         1.32            88         3.4
#
#    rating  total_sales
# 14      E        21.82
# 16      M        21.05
# ...

# %%
sales_leaders=actual_period.groupby('platform')['total_sales'].sum().sort_values(ascending = False )
sales_leaders
# Out:
# platform
# PS3     577.75
# X360    545.50
# PS4     313.39
# 3DS     249.40
# Wii     224.05
# XOne    159.23
# PC      124.33
# DS      122.26
# WiiU     80.12
# PSP      63.62
# PSV      51.74
# PS2       7.52
# PS        2.71
# GEN       2.67
# XB        0.10
# GC        0.05
# GBA       0.04
# Name: total_sales, dtype: float64

# %% [markdown]
# Прибыльные платформы с 2006 по 2016 годы: X360, PS3, Wii, DS, PS4, 3DS, PSP, PC, PS2, XOne, WiiU, PSV

# %% [markdown]
# ### Исправлено
# Прибыльные платформы с 2010 по 2016 годы: PS3, X360, PS4, 3DS, Wii, XOne, PC, DS, WiiU, PSP, PSV

# %% [markdown]
# Платформы у которых были продажи в 2016.

# %%
actual_period.query("year_of_release==2016").groupby('platform')['total_sales'].sum().sort_values(ascending = False)
# Out:
# platform
# PS4     66.06
# XOne    25.24
# 3DS     14.61
# PC       5.06
# PSV      4.23
# WiiU     3.89
# PS3      3.60
# X360     1.52
# Wii      0.18
# Name: total_sales, dtype: float64

# %% [markdown]
# Т.е. потенциально прибыльные платформы PS4, XOne, 3DS, PC, PSV, WiiU, PS3, X360. Построим для этих платформ диаграмму "ящик с усами".

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Да, именно эти платформы мы и можем назвать перспективными на 2017 год.
#
# </div>

# %%
dict_boxplot=actual_period.query("year_of_release==2016").groupby('platform')['total_sales'].sum().sort_values(ascending = False).index
perspective_platforms = actual_period.query('platform in @dict_boxplot').reset_index()
perspective_platforms.head()
# Out:
#    index                            name platform  year_of_release    genre  \
# 0     14              Kinect Adventures!     X360             2010     Misc
# 1     16              Grand Theft Auto V      PS3             2013   Action
# 2     23              Grand Theft Auto V     X360             2013   Action
# 3     29  Call of Duty: Modern Warfare 3     X360             2011  Shooter
# 4     31       Call of Duty: Black Ops 3      PS4             2015  Shooter
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     15.00      4.89      0.24         1.69            61         6.3      E
# 1      7.02      9.09      0.98         3.96            97         8.2      M
# 2      9.66      5.14      0.06         1.41            97         8.1      M
# 3      9.04      4.24      0.13         1.32            88         3.4      M
# 4      6.03      5.86      0.36         2.38           NaN         NaN    NaN
#
#    total_sales
# 0        21.82
# ...

# %%
perspective_platforms.boxplot(column="total_sales", by="platform", figsize = (15,7))
plt.ylim(0,2)
# Out:
# (0, 2)

# %% [markdown]
# Большой размах продаж у платформ PS3, PS4, X360 и XOne. Медиана продаж примерно равны у PS3 и X360, и у PS4 и XOne. Что говорит о том, что это конкурирующие платформы. Платформы Wii и WiiU, также имеют равный размах и равные медианы продаж. Менее меньший размах и медиана у 3DS, PC, и PSV.

# %%
actual_period.groupby('platform')['total_sales'].mean().sort_values(ascending=False)
# Out:
# platform
# GEN     2.670000
# PS      1.355000
# PS4     0.809793
# X360    0.797515
# PS3     0.658030
# XOne    0.649918
# WiiU    0.552552
# Wii     0.502354
# 3DS     0.496813
# PC      0.254775
# DS      0.243062
# PS2     0.150400
# PSP     0.128785
# PSV     0.124077
# XB      0.100000
# GC      0.050000
# GBA     0.040000
# Name: total_sales, dtype: float64

# %%
actual_period.query('platform=="GEN"')
# Out:
#               name platform  year_of_release     genre  na_sales  eu_sales  \
# 564  Mortal Kombat      GEN             2011  Fighting      1.95      0.63
#
#      jp_sales  other_sales  critic_score  user_score rating  total_sales
# 564       0.0         0.09           NaN         NaN    NaN         2.67

# %%
actual_period.query('platform=="PS"')
# Out:
#                  name platform  year_of_release    genre  na_sales  eu_sales  \
# 568    Medal of Honor       PS             2010  Shooter      1.44      1.09
# 13616      The Smurfs       PS             2011   Action      0.02      0.02
#
#        jp_sales  other_sales  critic_score  user_score rating  total_sales
# 568         0.0         0.14            92         8.6      T         2.67
# 13616       0.0         0.00           NaN         NaN    NaN         0.04

# %% [markdown]
# В среднем значении total_sales, появились две платформы, которые сейчас уже не актуальны.

# %%
perspective_platforms.groupby('platform')['total_sales'].mean().sort_values(ascending=False)
# Out:
# platform
# PS4     0.809793
# X360    0.797515
# PS3     0.658030
# XOne    0.649918
# WiiU    0.552552
# Wii     0.502354
# 3DS     0.496813
# PC      0.254775
# PSV     0.124077
# Name: total_sales, dtype: float64

# %% [markdown]
# Таким, образом перспективные платформы на которые следует ориентироваться: PS4, XOne, WiiU, 3DS. Это платформы нового поколения и у них были продажи в 2016 году. На втором месте платформы: PC и PSV. На PC хоть и не так много продаж, но для этой платформы всегда будут выходить игры и даже эмуляторы некоторых игровых консолей. Платформа PSV конкурент 3DS, поэтому, чтобы не терять потенциальных клиентов лучше поддержать продажи данной платформы. Платформы X360 и PS3 уже устарели и у них почти нулевые продажи в 2016, поэтому лучше постепенно отходить от продаж игр к этим платформам. У платформы Wii, судя по графику продаж, продажи почти на нуле, поэтому от этой платформы тоже стоит отказаться.

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Подумай, из-за чего формируется разница между платформами. Старайся не только описывать результат, но и трактовать его.
#
# </div>

# %% [markdown]
# ### Ответ
# Разница между игровыми платформами формируется:
# * Из-за новизны платформы. Т.е. более новая платформа более производительная и на ней более реалистичные игры. Например, PS3 и PS4, X360 и XOne;
# * Из-за того, что разные корпорации выпускают свои собственные платформы. Например, PS4 и XOne. Каждая корпорация пытается привлечь к себе клиентов, тем самым увеличить свою прибыль в игровой индустрии. Это проявляется ввиде конкуренции платформ;
# * Портативные и станционарные платформы. Некоторые корпорации делают ставки не только на стационарные, но и на портативные игровые платформы. Т.к. для игры на стационарной платформе, человеку надо прийти домой, включить телевизор. А для портативных платформ достаточно достать консоль из кармана. В итоге человек может играть в любых условиях: в пробке, в очереди, на обеде, а не только дома. Пример: 3DS и PSV
#
# Если мы хотим максимизировать продажи, то требуется охватить все возможные перспективные сегменты рынка и учитывать эти особенности.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Снова крутой разбор причин, молодец.
# </div>

# %% [markdown]
# * Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы и соотнесите их с продажами игр на других платформах.

# %% [markdown]
# Выберем данные без пропусков в полях rating, user_score и critic_score.

# %%
perspective_platforms_not_null=(perspective_platforms
                                [perspective_platforms['rating'].notnull() &
                                perspective_platforms['user_score'].notnull() & 
                                perspective_platforms['critic_score'].notnull()])

# %% [markdown]
# Проверим влияние отзывов пользователей и критиков на продажи игр к платформе X360.

# %%
x360_df = perspective_platforms_not_null.query('platform == "X360"')
x360_df.plot(x='user_score', y='total_sales', kind='hexbin', 
              gridsize=30, figsize=(15, 7), sharex=False, grid=True )

# %%
x360_df.plot(x='critic_score', y='total_sales', kind='hexbin', 
              gridsize=30, figsize=(15, 7), sharex=False, grid=True )

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Графики стоит перевернуть. По оси X указывается независимая переменная.
#
# </div>

# %% [markdown]
# ### Ответ
# Исправлено

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# 👍
#
# </div>

# %%
features = ['user_score', 'critic_score', 'total_sales']
sns.heatmap(x360_df[features].corr(), annot=True, cmap="Greens", fmt='.2f', annot_kws={'size':16})

# %% [markdown]
# Коэффицент корреляции Пирсона для полей total_sales и user_score составляет 0.11, что говорит о слабой связи этих параметров или что связь имеет более сложный, нелинейный характер. Диаграмма расеивания показывает, что пользовательский рейтинг игр user_score не влияет на продажи total_sales.
#
# Коэффицент корреляции Пирсона для полей total_sales и critic_score составляет 0.39. Это означает, что между critic_score и total_sales есть слабая положительная связь. Диаграмма рассеивания этих величин, показывает эту связь. Т.е. значение critic_score слабо влияет на величину продаж total_sales.

# %% [markdown]
# Проверим эти выводы на платформах PS4 и XOne.

# %%
PS4 = perspective_platforms_not_null.query('platform == "PS4"')
PS4.plot(x='user_score', y='total_sales', kind='hexbin', 
              gridsize=30, figsize=(15, 7), sharex=False, grid=True )

# %%
PS4.plot(x='critic_score', y='total_sales', kind='hexbin', 
              gridsize=30, figsize=(15, 7), sharex=False, grid=True )

# %%
plt.figure(figsize=(4,4))
sns.heatmap(PS4[features].corr(), annot=True, cmap="Greens", fmt='.2f', annot_kws={'size':16})

# %%
XOne = perspective_platforms_not_null.query('platform == "XOne"')
XOne.plot(x='user_score', y='total_sales', kind='hexbin', 
              gridsize=30, figsize=(15, 7), sharex=False, grid=True )

# %%
XOne.plot(x='critic_score', y='total_sales', kind='hexbin', 
              gridsize=30, figsize=(15, 7), sharex=False, grid=True )

# %%
plt.figure(figsize=(4,4))
sns.heatmap(XOne[features].corr(), annot=True, cmap="Greens", fmt='.2f', annot_kws={'size':16})

# %% [markdown]
# Т.е. как показали последние диаграммы расеивания и коэффицент корреляции Пирсона, значение user_score не влияет на продажи total_sales. Отзывы критиков critic_score слабо влияют на total_sales. Т.е. чем выше critic_score у игры, тем больше вероятность, что её продажи будут расти.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Результат получен. Подумай, чем он вызван. Здорово, что рассмотрены несколько платформ.
#
# </div>

# %% [markdown]
# ### Ответ
# Возможно critic_score влияет на продажи, т.к. возможно, что перед покупкой игры, пользователи смотрят её обзор, где как раз и появляется оценка критиков. И по этой оценке и по отзыву в обзоре делают вывод: покупать игру или нет.

# %% [markdown]
# * Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %% [markdown]
# Посмотрим графики распределения для всех платформ с 2006 по 2016 годы.

# %%
(actual_period.groupby('genre')['total_sales'].sum()
                .sort_values(ascending=False)
                .plot(kind='bar', y='total_sales', figsize=(10, 5), legend=False)
                .set(xlabel='Жанр', ylabel='Глобальные продажи'))
plt.show()

# %% [markdown]
# Наиболее прибыльные жанры это Action, Shooter, Sports, Role-Playing. Наименее прибыльные жанры Strategy, Puzzle и Adventure.

# %% [markdown]
# Посмотрим распределение игр для перспективных платформ.

# %%
perspective_platforms['platform'].unique()
# Out:
# array(['X360', 'PS3', 'PS4', '3DS', 'Wii', 'XOne', 'WiiU', 'PC', 'PSV'],
#       dtype=object)

# %%
(perspective_platforms.groupby('genre')['total_sales'].sum()
                .sort_values(ascending=False)
                .plot(kind='bar', y='total_sales', figsize=(10, 5), legend=False)
                .set(xlabel='Жанр', ylabel='Глобальные продажи'))
plt.show()

# %% [markdown]
# Т.е. аналогично наиболее прибыльные жанры это Action, Shooter, Sports, Role-Playing. Наименее прибыльные жанры - Strategy, Puzzle и Adventure. Возможно пользователям нехватает острых эмоций и приключений, а кто-то мечтал быть спортсменом, поэтому эти жанры игр и сыскали такую популярность.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Анализ популярности жанров проведен. Однако не стоит забывать, что производство игр в жанрах Action или Shooter обходится сильно дороже, чем производство Puzzle-игр.
#
# </div>

# %% [markdown]
# # Шаг 5. Составьте портрет пользователя каждого региона
# Определите для пользователя каждого региона (NA, EU, JP):
# * Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# * Самые популярные жанры (топ-5). Поясните разницу.
# * Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %% [markdown]
# Возьмём данные из таблицы actual_period.

# %%
plt.style.use('seaborn')

# %%
sum_na_sales=actual_period['na_sales'].sum()
sum_eu_sales=actual_period['eu_sales'].sum()
sum_jp_sales=actual_period['jp_sales'].sum()
actual_period['ratio_na_sales']=actual_period['na_sales']/sum_na_sales
actual_period['ratio_eu_sales']=actual_period['eu_sales']/sum_na_sales
actual_period['ratio_jp_sales']=actual_period['jp_sales']/sum_na_sales

# %%
def top5_platform(df, region):
    ratio='ratio_'+region
    result=df.groupby('platform')[region, ratio].sum().sort_values(by=region, ascending=False).head()
    return result

# %%
def top5_genre(df, region):
    result=df.groupby('genre')[region].sum().sort_values(ascending=False).head()
    return result

# %%
def rating_sales(df, region):
    result=df.groupby('rating')[region].sum().sort_values(ascending=False)
    return result

# %%
def plot_total_region(df, region, xlabel, ylabel):
    (df.plot(kind='bar', y=region, figsize=(10, 5), legend=False, title=region)
                        .set(xlabel=xlabel, ylabel=ylabel))

# %% [markdown]
# ### Исправлено

# %% [markdown]
# Поле rating содержит значение nan. Для учёта игр неимеющих рейтинга заполним отсутствующие значения - значением no_rating.

# %%
actual_period['rating'].unique()
# Out:
# array(['E', 'M', nan, 'E10+', 'T', 'EC', 'RP'], dtype=object)

# %%
actual_period['rating']=actual_period['rating'].fillna('no_rating')

# %%
actual_period['rating'].unique()
# Out:
# array(['E', 'M', 'no_rating', 'E10+', 'T', 'EC', 'RP'], dtype=object)

# %%
actual_period[actual_period['rating']=='no_rating']
# Out:
#                                             name platform  year_of_release  \
# 27                   Pokemon Black/Pokemon White       DS             2010
# 31                     Call of Duty: Black Ops 3      PS4             2015
# 33                           Pokemon X/Pokemon Y      3DS             2013
# 47     Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS             2014
# 72                                     Minecraft     X360             2013
# ...                                          ...      ...              ...
# 16703                           Strawberry Nauts      PSV             2016
# 16707                           Aiyoku no Eustia      PSV             2014
# 16710              Samurai Warriors: Sanada Maru      PS3             2016
# 16712                    Haitaka no Psychedelica      PSV             2016
# 16714                        Winning Post 8 2016      PSV             2016
#
# ...

# %%
actual_period[actual_period['rating']=='no_rating'].groupby('genre')['name'].count().sort_values(ascending=False)
# Out:
# genre
# Action          597
# Adventure       418
# Role-Playing    283
# Misc            265
# Sports          152
# Strategy         90
# Simulation       80
# Shooter          64
# Fighting         64
# Racing           51
# Puzzle           37
# Platform         28
# Name: name, dtype: int64

# %% [markdown]
# Среди игр, с отсутствующим рейтингом, много игр жанров Action, Adventure, Role-Playing.

# %% [markdown]
# Возможно, что отсутствующее значение рейтинга связано с тем, что рейтинг этим играм выставлен по другой системе, не организацией ESRB.

# %% [markdown]
# ### Северная Америка, na_sales.

# %%
region='na_sales'

# %%
top5_platform(actual_period, region)
# Out:
#           na_sales  ratio_na_sales
# platform
# X360        331.58        0.295134
# PS3         226.07        0.201221
# Wii         121.05        0.107745
# PS4         108.52        0.096592
# XOne         93.06        0.082831

# %%
plot_total_region(top5_platform(actual_period, region), region, 'Платформа','Продажи')

# %% [markdown]
# Самые популярные платформы X360, Wii, PS3. PS4 только на пятом месте.

# %%
top5_genre(actual_period, region)
# Out:
# genre
# Action          290.47
# Shooter         239.74
# Sports          156.65
# Misc            120.23
# Role-Playing    109.04
# Name: na_sales, dtype: float64

# %%
plot_total_region(top5_genre(actual_period, region), region, 'Жанр','Продажи')

# %% [markdown]
# Самые популярные жанры - Action, Shooter, Sports, Role-Playing.

# %%
rating_sales(actual_period, region)
# Out:
# rating
# M            384.26
# E            269.62
# E10+         161.49
# T            156.79
# no_rating    150.20
# EC             1.13
# RP             0.00
# Name: na_sales, dtype: float64

# %%
plot_total_region(rating_sales(actual_period, region), region, 'Ретинг ESRB','Продажи')

# %% [markdown]
# По данному рейтингу можно определить целевую аудиторию пользователей игр.
#
# В Северной Америке больше всего покупают игр рейтинга E, что показывает, то, что основными пользователями игр являются дети от 6 лет. Следующая категория M - аудитория от 17 лет. Далее T - подростки от 13 лет. И дети от 10 лет. А игры для самых маленьких - EC от 3 лет в Севереной Америке не имеют интерес.

# %% [markdown]
# ### Исправлено
# Также в Северной Америке популярны игры которые не имеют возрастного рейтинга организации ESRB.

# %% [markdown]
# ### Европа, eu_sales

# %%
region='eu_sales'

# %%
top5_platform(actual_period, region)
# Out:
#           eu_sales  ratio_eu_sales
# platform
# PS3         210.00        0.186918
# X360        161.52        0.143766
# PS4         140.85        0.125368
# PC           70.07        0.062368
# Wii          66.06        0.058799

# %%
plot_total_region(top5_platform(actual_period, region), region, 'Платформа','Продажи')

# %% [markdown]
# Самые популярные платформы PS3, X360, PS4, PC и Wii

# %%
top5_genre(actual_period, region)
# Out:
# genre
# Action          233.21
# Shooter         173.61
# Sports          116.45
# Role-Playing     74.01
# Misc             65.98
# Name: eu_sales, dtype: float64

# %%
plot_total_region(top5_genre(actual_period, region), region, 'Жанр','Продажи')

# %% [markdown]
# Как и в Северной Америке троика самых популярных жанров - Action, Shooter, Sports и Role-Playing.

# %%
rating_sales(actual_period, region)
# Out:
# rating
# M            293.95
# E            196.52
# no_rating    133.80
# T            110.17
# E10+         101.15
# RP             0.03
# EC             0.00
# Name: eu_sales, dtype: float64

# %%
plot_total_region(rating_sales(actual_period, region), region, 'Рейтинг ESRB','Продажи')

# %% [markdown]
# В Европе как и в Северной Америке, основные целевые аудитории игр это: дети от 6 лет, подростки от 17 лет, подростки от 13 лет и дети от 10 лет.

# %% [markdown]
# ### Исправлено
# В Европе также много игр, которые не имеют возрастного рейтинга организации ESRB.

# %% [markdown]
# ### Япония, jp_sales

# %%
region='jp_sales'

# %%
top5_platform(actual_period, region)
# Out:
#           jp_sales  ratio_jp_sales
# platform
# 3DS          96.75        0.086116
# PS3          57.57        0.051242
# PSP          41.73        0.037143
# DS           28.16        0.025065
# PSV          21.38        0.019030

# %%
plot_total_region(top5_platform(actual_period, region), region, 'Платформа','Продажи')

# %% [markdown]
# В Японии ситуация совершенно иная - популярны игровые консоли от Nintendo. 3DS, PS3, PSP, DS, PSV.

# %%
top5_genre(actual_period, region)
# Out:
# genre
# Role-Playing    100.22
# Action           70.72
# Misc             24.54
# Platform         15.81
# Adventure        15.67
# Name: jp_sales, dtype: float64

# %% [markdown]
# В Японии пользуются спросом игры жанра Role-Playing, Action, Platform, Adventure.

# %%
plot_total_region(top5_genre(actual_period, region), region, 'Жанр','Продажи')

# %%
rating_sales(actual_period, region)
# Out:
# rating
# no_rating    166.63
# E             47.85
# T             42.24
# M             30.46
# E10+          13.17
# RP             0.00
# EC             0.00
# Name: jp_sales, dtype: float64

# %%
plot_total_region(rating_sales(actual_period, region), region, 'Рейтинг ESRB','Продажи')

# %% [markdown]
# В Японии, основные целевые аудитории игр это: дети от 6 лет, подростки от 13 лет, подростки от 17 лет, и дети от 10 лет.

# %% [markdown]
# ### Исправлено
#
# В Японии игры не имеющие возрастного рейтинга организации ESRB, стоят на первом месте по популярности.

# %% [markdown]
# ### Дополнено
# В разных странах представлены разные рейтинговые модели: американская ESRB, европейская PEGI, японская CERO. В полученных данных фигурирует только рейтинг от организации ESRB. Все страны производят игры, поэтому каждая игра получает рейтинг рейтинговой модели своей страны. Для более полного анализа данных по ретингам, требуется получить рейтинги игр от остальных организаций.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Обрати внимание - ты не учитываешь игры без рейтинга. В результате огромная часть игр просто выпадает из анализа. Найди способ учесть их при группировке значений по рейтингу.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Круто, что ты не просто получил результат, но также и обосновал причины его появления. Это правда здорово)
#
# </div>

# %% [markdown]
# При формировании предложении о продажах игр, для различных регионов, требуется учитывать данные особенности.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Портрет типичного пользователя каждого из регионов получен. Стоит визуализировать все полученные таблицы. Крайне не хватает графиков в данном разделе работы.
#
# </div>

# %% [markdown]
# ### Ответ
# На каждый регион и по каждой исследованной характеристики добавлены графики.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Старайся всегда визуализировать получаемую в работе информацию.
#
# </div>

# %% [markdown]
# ### Дополнено
# На каждом этапе анализа у меня идёт вызов одних и тех же функций, в той же последовательности. Это можно автоматизировать. Также можно применить виджеты jupiter notebook. При написании кода этого ноутбука я заметил, что приходится писать много однотипного кода, в дальнейшем, чтобы не запутаться требуется написать какой-нибудь обощённый код, типа движка.

# %% [markdown]
# # Шаг 6. Проведите исследование статистических показателей
# * Как изменяется пользовательский рейтинг и рейтинг критиков в различных жанрах? Посчитайте среднее количество, дисперсию и стандартное отклонение. Постройте гистограммы. Опишите распределения

# %% [markdown]
# #### Пользовательский рейтинг, user_score

# %%
actual_period.groupby('genre').agg({'user_score':['mean', 'median', 'count', 'var', 'std']})
# Out:
#              user_score
#                    mean median count       var       std
# genre
# Action         6.785623    7.1   786  1.843678  1.357821
# Adventure      7.350000    7.7   106  1.731286  1.315783
# Fighting       6.957692    7.3   130  1.752227  1.323717
# Misc           6.619286    6.8   140  2.284158  1.511343
# Platform       7.066990    7.7   103  2.759880  1.661289
# Puzzle         7.220833    7.4    24  1.166069  1.079847
# Racing         6.367133    6.6   143  2.520954  1.587751
# Role-Playing   7.287879    7.5   264  1.452400  1.205156
# Shooter        6.492073    6.7   328  2.353331  1.534057
# Simulation     6.226250    6.6    80  2.818669  1.678889
# Sports         5.891798    6.2   317  2.897654  1.702250
# Strategy       6.693976    7.1    83  2.902280  1.703608

# %% [markdown]
# Уникальные значения пользовательского рейтинга.

# %%
actual_period['user_score'].unique()
# Out:
# array([6.3, 8.2, 8.1, nan, 3.4, 5.3, 4.8, 3.2, 6.4, 8.3, 8.4, 7.5, 2.6,
#        7.8, 7.2, 7.9, 7. , 7.3, 8.7, 4.3, 7.4, 6.6, 5.7, 5. , 9.1, 6.5,
#        8.8, 6.9, 8.6, 9. , 6.1, 6.7, 5.4, 4. , 8. , 8.5, 4.9, 4.5, 6.2,
#        4.2, 7.7, 9.2, 7.6, 3.7, 4.1, 5.8, 5.6, 6.8, 5.5, 4.4, 5.9, 8.9,
#        3.9, 3.1, 2.9, 7.1, 6. , 4.7, 5.1, 3.5, 2.5, 3. , 5.2, 2.7, 2.2,
#        2.1, 3.3, 1.8, 3.8, 4.6, 9.3, 1.6, 3.6, 2.4, 2.8, 1.7, 2. , 1.5,
#        0.7, 0.5, 0.2, 1.4, 1.2, 0.9, 1.9, 1.3, 1. , 2.3])

# %%
# цвета, для наглядного изображения графиков
colors=['aqua', 'navy', 'blue', 'black', 'brown', 'coral', 'green', 'olive', 'red', 'yellow', 'orange', 'sienna', 'purple', 'violet']

# %% [markdown]
# Построим гистограммы пользовательского рейтинга, по каждому жанру.

# %%
genres=list(actual_period['genre'].unique())
rows = len(genres)
fig, ax = plt.subplots(rows, figsize=(10, 30))
num=0
for genre, color in zip(actual_period['genre'].unique(), colors):
    #actual_period[actual_period['genre']==genre]['user_score'].hist(ax=ax[num], color=color)
    actual_period[actual_period['genre']==genre]['user_score'].plot(ax=ax[num], kind='hist', bins=10, title=genre)
    num+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# Все распределения скошены слева. Это показывает, что пользователи в основном ставят играм низкие оценки. Возможно, что это ещё одна причина почему снижаются продажи игр. Т.е. пользователям в большинстве не нравятся выпускаемые игры и они им ставят низкие оценки.

# %% [markdown]
# Для наглядности посмотрим гисторгамму плотности распределения пользовательского рейтинга по каждому жанру.

# %%
for genre, color in zip(actual_period['genre'].unique(), colors):
    actual_period[actual_period['genre']==genre]['user_score'].plot(kind = 'density' , grid = True, figsize = (15,7),
                                    linewidth = 3, alpha = 0.7, legend = True, label=genre, color=color)
    plt.legend()

# %% [markdown]
# #### Оценка критиков, critic_score

# %%
actual_period.groupby('genre').agg({'critic_score':['mean', 'median', 'count', 'var', 'std']})
# Out:
#              critic_score
#                      mean median count         var        std
# genre
# Action          68.854972   71.0   724  181.203004  13.461167
# Adventure       70.285714   72.0    98  162.515464  12.748155
# Fighting        70.073171   74.0   123  187.281487  13.685083
# Misc            68.826087   72.5   138  162.772453  12.758231
# Platform        74.489583   77.0    96  171.515680  13.096399
# Puzzle          72.387097   74.0    31   70.245161   8.381239
# Racing          70.934783   73.0   138  175.696446  13.255054
# Role-Playing    72.992157   74.0   255  146.740096  12.113633
# Shooter         72.104235   75.0   307  187.270145  13.684668
# Simulation      64.184211   66.0    76  160.285614  12.660395
# Sports          70.360902   75.0   266  242.073032  15.558696
# Strategy        73.473684   76.5    76  153.985965  12.409108

# %% [markdown]
# Уникальные значения оценки критиков.

# %%
actual_period['critic_score'].unique()
# Out:
# <IntegerArray>
# [ 61,  97, NaN,  88,  87,  83,  85,  90,  84,  73,  74,  78,  91,  71,  96,
#   82,  68,  92,  95,  86,  76,  93,  81,  80,  89,  94,  77,  56,  70,  72,
#   79,  75,  66,  42,  64,  67,  57,  65,  55,  63,  54,  33,  59,  52,  60,
#   69,  45,  53,  62,  47,  48,  39,  49,  51,  43,  40,  50,  32,  58,  41,
#   34,  38,  44,  46,  31,  26,  36,  23,  35,  24,  37,  21,  19,  28,  20,
#   25,  13]
# Length: 77, dtype: Int64

# %% [markdown]
# Гистограммы оценки критиков, по каждому жанру.

# %%
genres=list(actual_period['genre'].unique())
rows = len(genres)
fig, ax = plt.subplots(rows, figsize=(10, 30))
num=0
for genre, color in zip(actual_period['genre'].unique(), colors):
    #actual_period[actual_period['genre']==genre]['user_score'].hist(ax=ax[num], color=color)
    actual_period[actual_period['genre']==genre]['critic_score'].plot(ax=ax[num], kind='hist', bins=10, title=genre)
    num+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# Опять наблюдается скошенность слева по каждому жанру. Это показывает, преобладание низких оценок игр критиками. Критикам тоже, в основном, не нравятся игры.

# %% [markdown]
# Посмотрим гистограмму плотности распределения рейтинга критиков по каждому жанру.

# %%
for genre, color in zip(actual_period['genre'].unique(), colors):
    actual_period[actual_period['genre']==genre]['critic_score'].astype('float').plot(kind = 'density' , grid = True, figsize = (15,7),
                                    linewidth = 3, alpha = 0.7, legend = True, label=genre, color=color)
    plt.legend()

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Результат получен. Здорово, что ты не просто описал наблюдения, но также и привел возможные причины появления таких значений.
#
# </div>

# %% [markdown]
# # Шаг 7. Проверьте гипотезы

# %% [markdown]
# * Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# * Средние пользовательские рейтинги жанров Action (англ. «действие») и Sports (англ. «виды спорта») разные.
# Задайте самостоятельно пороговое значение alpha.
#
# Поясните:
# * Как вы сформулировали нулевую и альтернативную гипотезы;
# * Какой критерий применили для проверки гипотез и почему.

# %% [markdown]
# Будем использовать t-критерий Стьюдента, так как сравниваемые выборки независимы между собой.

# %% [markdown]
# #### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.

# %% [markdown]
# Н0 (нулевая гипотеза) - cредние пользовательские рейтинги платформ Xbox One и PC одинаковые.
#
# Н1 (альтернативная гипотеза) - средние пользовательские рейтинги платформ Xbox One и PC отличаются между собой.

# %% [markdown]
# Для проверки гипотезы возьмём набор данных actual_period.

# %%
xone = actual_period.query('platform == "XOne"')
pc = actual_period.query('platform == "PC"')

# %%
alpha = .05

# %% [markdown]
# Возьмём значение стандартное значение alpha 0.05

# %% [markdown]
# Проверим равны ли дисперсии сравниваемых выборок.

# %%
xone['user_score'].var()
# Out:
# 1.888588090853284

# %%
pc['user_score'].var()
# Out:
# 2.4222001209272928

# %% [markdown]
# Дисперсии не равны, поэтому для проведения t-критерий Стьюдента, будем использовать параметр equal_var=False.

# %%
results = st.ttest_ind(
    xone['user_score'],
    pc['user_score'],
    equal_var=False,  # Welch’s t-test, который не предполагает равенство дисперсий
    nan_policy='omit' # игнорируем пропуски
)

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.9239941819039786
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Действительно, посчитаем средние значения пользовательского рейтинга для XOne и PC.

# %%
pc['user_score'].mean()
# Out:
# 6.521204188481675

# %%
xone['user_score'].mean()
# Out:
# 6.508839779005524

# %% [markdown]
# Средние значения примерно равны, принимаем нулевую гипотезу.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Гипотезы сформулированы и проверены верно.
#
# </div>

# %% [markdown]
# #### Средние пользовательские рейтинги жанров Action (англ. «действие») и Sports (англ. «виды спорта») разные.

# %% [markdown]
# Н0 (нулевая гипотеза) - средние пользовательские рейтинги жанров Action и Sports одинаковые.
#
# Н1 (альтернативная гипотеза) - средние пользовательские рейтинги жанров Action и Sports отличаются между собой.

# %%
alpha = .05

# %% [markdown]
# Также возьмём стандартное значение параметра alpha=0.05 и проверим равенство дисперсий двух выборок

# %%
action = actual_period.query("genre == 'Action'")
sports = actual_period.query("genre == 'Sports'")

# %%
action['user_score'].var()
# Out:
# 1.843678400674219

# %%
sports['user_score'].var()
# Out:
# 2.897654035059697

# %% [markdown]
# Дисперсии выборок опять не равны, поэтому снова будем использовать параметр equal_var=False

# %%
results = st.ttest_ind(
    action['user_score'],
    sports['user_score'],
    equal_var=False,
    nan_policy='omit' # игнорируем пропуски
)

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 7.721055898896968e-16
# Отвергаем нулевую гипотезу

# %% [markdown]
# Проверим средние значения:

# %%
action['user_score'].mean()
# Out:
# 6.785623409669212

# %%
sports['user_score'].mean()
# Out:
# 5.8917981072555206

# %% [markdown]
# Они довольно значительно отличаются.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Прежде чем произвести проверку гипотезы через T-критерий Стьюдента произведи проверку дисперсии выборок, чтобы понять с каким параметром использовать метод проверки. Параметр equal_var ты уточнил при проверке первой гипотезы. Однако не совсем ясно, почему мы должны использовать именно False. Обоснуй данный выбор.
#
# </div>

# %% [markdown]
# ### Ответ
# Проверка равенства дисперсий выполнена.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Да, теперь выбор параметра обоснован.
#
# </div>

# %% [markdown]
# # Общий выводы по проведённому исследованию данных:

# %% [markdown]
# 1)	Набор данных изначально содержит довольно много пропусков в полях, задающих индивидуальные характеристики игр:
#
# * Поле rating, не заполненных значений - 6699, 40.44% от всего набора данных.
# * Поле user_score, не заполненных значений - 6633, 40.04% от всего набора данных.
# * Поле critic_score, не заполненных значений - 8492, 51.26% от всего набора данных.
#
# Поэтому анализ данных с применением этих полей, может не достоверно отобразить общие тенденции игровой индустрии. В данной ситуации требуется обратиться к Data-инженерам, к специалистам, которые предоставили данные или произвести повторную загрузку недостающих данных с источника.
#
# 2) Продажи и выпуск игр идёт на спад. Срок жизни платформ составляет от 7 до 12 лет. Перспективные платформы: PS4, XOne, WiiU, 3DS. Далее PC и PSV. Платформы X360 и PS3 хоть и имели большие продажи в прошлом, но они уже устарели и продажи игр к этим платформам уже упали. Аналогичная ситуация с платформой Wii, почти нулевые продажи.
#
# 3) На продажи игр больше влияет рейтинг критиков, чем рейтинг пользователей.
#
# 4) Наиболее прибыльные и популярные игры жанров Action, Shooter, Sports, Role-Playing. Наименее - Strategy, Puzzle и Adventure.
#
# 5) Для успешных продаж игр следует учитывать популярные жанры, платформы и возраст пользователей игр в зависимости от региона продаж.
#
# 6) По гистограммам рейтинга критиков и пользовательского рейтинга, по каждому жанру, заметно небольшое преобладание низких оценок. Это говорит о том, что игры стали меньше нравиться критикам и пользователям.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Выводы описаны грамотно. Приведены ответы на главные вопросы проекта. В выводах можно приводить полученные ранее значения. Также можно расписать все, что было сделано в ходе проведения работы. Еще лучше будет, если приведешь рекомендации для компании по дальнейшим действиям.
#
# </div>

# %% [markdown]
# 1) Продажи игр в снижающимся тренде. Продажи игр падают. Постепенно следует выходить из этого бизнеса. Возможно, ситуацию спасут новые технологии, например технология виртуальной реальности, игры для мобильных устройств;
#
# 2) Перспективные платформы: PS4, XOne, WiiU, 3DS, PC, PSV. В первую очередь, желательно продавать игры этих платформ. Т.к. эти платформы ещё будут держаться некоторое время;
#
# 3) Желательно продавать игры жанров Action, Shooter, Sports, Role-Playing. Не желательно продавать игры - Strategy, Puzzle и Adventure;
#
# 4) Для каждого региона продаж: Северная Америка, Европа, Япония, желательно учитывать популярные жанры, платформы и возраст пользователей игр. Для более детального анализа требуется дополнить данные европейским рейтингом PEGI, и японским CERO;
#
# 5) Для успешных продаж игр, в первую очередь следует ориентироваться на рейтинг критиков.

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Если тебе нравится тема визуализации, то можешь изучить другие методы библиотеки seaborn. Она позволяет строить довольно презентабельные графики. Круто, что ты вообще используешь данную библиотеку.
#
# Ты проделал большую работу, молодец! Критических замечаний немного. Однако с ними важно поработать и их исправить. Также есть достаточное число желтых комментариев. Думаю, исправить их тебе не составит труда. Жду твою работу :)
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Помарки исправлены, и теперь работа выполнена хорошо. Ты проделал просто отличную работу над ошибками, молодец. Поздравляю со сданным проектом. Надеюсь, он был интересен и познавателен. Спасибо за оставленные комменатрии по исправлениям. Успехов в дальнейшем пути :)
#
# </div>
